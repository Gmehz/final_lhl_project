# %% [markdown]
# ### **Step 1: Analyzing the dataset to gain preliminary understanding**

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the file
df =pd.read_csv('Symptom2Disease.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      label                                               text
# 0           0  Psoriasis  I have been experiencing a skin rash on my arm...
# 1           1  Psoriasis  My skin has been peeling, especially on my kne...
# 2           2  Psoriasis  I have been experiencing joint pain in my fing...
# 3           3  Psoriasis  There is a silver like dusting on my skin, esp...
# 4           4  Psoriasis  My nails have small dents or pits in them, and...

# %%
# Print a random sample row
df.sample()
# Out:
#      Unnamed: 0             label  \
# 300           0  Fungal infection
#
#                                                   text
# 300  I have raised lumps, a rash that looks red and...

# %%
# Print the size of the dataset
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 1200
# Number of columns: 3

# %%
# Print the column names and their data types
print(df.dtypes)
# Out:
# Unnamed: 0     int64
# label         object
# text          object
# dtype: object

# %%
# Print the number of missing values in each column
print(df.isnull().sum())
# Out:
# Unnamed: 0    0
# label         0
# text          0
# dtype: int64

# %%
# Unique labels
print(df['label'].unique())
# Out:
# ['Psoriasis' 'Varicose Veins' 'Typhoid' 'Chicken pox' 'Impetigo' 'Dengue'
#  'Fungal infection' 'Common Cold' 'Pneumonia' 'Dimorphic Hemorrhoids'
#  'Arthritis' 'Acne' 'Bronchial Asthma' 'Hypertension' 'Migraine'
#  'Cervical spondylosis' 'Jaundice' 'Malaria' 'urinary tract infection'
#  'allergy' 'gastroesophageal reflux disease' 'drug reaction'
#  'peptic ulcer disease' 'diabetes']

# %%
# Print the distribution of the target variable
# This will show the count of each unique value in the 'label' column
print(df['label'].value_counts())
# Out:
# Psoriasis                          50
# Varicose Veins                     50
# peptic ulcer disease               50
# drug reaction                      50
# gastroesophageal reflux disease    50
# allergy                            50
# urinary tract infection            50
# Malaria                            50
# Jaundice                           50
# Cervical spondylosis               50
# Migraine                           50
# Hypertension                       50
# Bronchial Asthma                   50
# Acne                               50
# Arthritis                          50
# Dimorphic Hemorrhoids              50
# Pneumonia                          50
# Common Cold                        50
# Fungal infection                   50
# Dengue                             50
# Impetigo                           50
# Chicken pox                        50
# Typhoid                            50
# diabetes                           50
# Name: label, dtype: int64

# %%
# Number of duplicated rows
print(df.duplicated().sum())
# Out:
# 0

# %%
# Text and word count analysis
df['description_length'] = df['text'].apply(len) # Create new column description_length
df['word_count'] = df['text'].apply(lambda x: len(x.split())) # Create new column word_count

# Plotting histogram for description lengths and word counts
sns.histplot(df['description_length']).set_title('Description Length Distribution')
plt.show()

sns.histplot(df['word_count']).set_title('Word Count Distribution')
plt.show()

# %%
# Create word cloud for each disease
from wordcloud import WordCloud

# Get unique diseases
diseases = df['label'].unique()

# Define the number of rows and columns for the subplot grid.
n_cols = 3  
n_rows = int(len(diseases) / n_cols) + (len(diseases) % n_cols > 0)

fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, 15)) 
axs = axs.ravel() 

for idx, disease in enumerate(diseases):
    text = ' '.join(df[df['label'] == disease]['text'])
    wordcloud = WordCloud(background_color="white", max_words=100).generate(text)
    
    axs[idx].imshow(wordcloud, interpolation='bilinear')
    axs[idx].set_title(disease)
    axs[idx].axis('off')

for idx in range(len(diseases), n_cols*n_rows):
    axs[idx].axis('off')

plt.tight_layout()

# Save the figure with padding
plt.savefig("wordclouds_for_diseases.png", dpi=300, pad_inches=0.5)

plt.show()

# %%
plt.figure(figsize=(12, 10))
sns.countplot(data=df, y='label', order=df['label'].value_counts().index)
plt.title('Disease Distribution')
plt.show()

# %%
# Count of unique symptom descriptions by disease
unique_symptoms = df.groupby('label')['text'].nunique()
print(unique_symptoms)
# Out:
# label
# Acne                               46
# Arthritis                          46
# Bronchial Asthma                   49
# Cervical spondylosis               49
# Chicken pox                        49
# Common Cold                        49
# Dengue                             50
# Dimorphic Hemorrhoids              41
# Fungal infection                   50
# Hypertension                       50
# Impetigo                           50
# Jaundice                           38
# Malaria                            44
# Migraine                           47
# Pneumonia                          47
# Psoriasis                          50
# Typhoid                            50
# Varicose Veins                     50
# allergy                            50
# diabetes                           50
# drug reaction                      50
# gastroesophageal reflux disease    48
# peptic ulcer disease               50
# urinary tract infection            50
# Name: text, dtype: int64

# %%
# Count nuber of duplicate rows for each disease
duplicate_counts = {}  # Dictionary to store counts for each disease

# Loop through each disease to find and count duplicates
for disease in df['label'].unique():
    disease_data = df[df['label'] == disease]
    duplicates = disease_data[disease_data.duplicated(subset='text', keep=False)]
    
    duplicate_counts[disease] = len(duplicates)

print(duplicate_counts)
# Out:
# {'Psoriasis': 0, 'Varicose Veins': 0, 'Typhoid': 0, 'Chicken pox': 2, 'Impetigo': 0, 'Dengue': 0, 'Fungal infection': 0, 'Common Cold': 2, 'Pneumonia': 6, 'Dimorphic Hemorrhoids': 17, 'Arthritis': 7, 'Acne': 8, 'Bronchial Asthma': 2, 'Hypertension': 0, 'Migraine': 6, 'Cervical spondylosis': 2, 'Jaundice': 22, 'Malaria': 12, 'urinary tract infection': 0, 'allergy': 0, 'gastroesophageal reflux disease': 4, 'drug reaction': 0, 'peptic ulcer disease': 0, 'diabetes': 0}

# %%
# Loop through each disease to find and display duplicates
for disease in df['label'].unique():
    disease_data = df[df['label'] == disease]
    duplicates = disease_data[disease_data.duplicated(subset='text', keep=False)]
    
    if not duplicates.empty:
        print(f"Duplicates for {disease}:")
        print(duplicates)
        print("\n")
# Out:
# Duplicates for Chicken pox:
#      Unnamed: 0        label  \
# 151         151  Chicken pox
# 163         163  Chicken pox
#
#                                                   text  description_length  \
# 151  I'm feeling fatigued and have no energy. I can...                 150
# 163  I'm feeling fatigued and have no energy. I can...                 150
#
#      word_count
# 151          27
# 163          27
#
#
# Duplicates for Common Cold:
#      Unnamed: 0        label  \
# 358          58  Common Cold
# 387          87  Common Cold
#
#                                                   text  description_length  \
# 358  I've been quite exhausted and ill. My throat h...                 200
# 387  I've been quite exhausted and ill. My throat h...                 200
#
#      word_count
# 358          37
# 387          37
#
#
# Duplicates for Pneumonia:
#      Unnamed: 0      label                                               text  \
# 414         114  Pneumonia  I have a really high fever, and I have problem...
# 424         124  Pneumonia  I'm having a hard time breathing and I feel re...
# 430         130  Pneumonia  I have a really high fever, and I have problem...
# 433         133  Pneumonia  I'm having a hard time breathing and I feel re...
# 436         136  Pneumonia  Lately I've been experiencing chills, fatigue,...
# 438         138  Pneumonia  Lately I've been experiencing chills, fatigue,...
#
#      description_length  word_count
# 414                 197          36
# 424                 210          40
# 430                 197          36
# 433                 210          40
# 436                 220          37
# 438                 220          37
#
#
# Duplicates for Dimorphic Hemorrhoids:
#      Unnamed: 0                  label  \
# 467         167  Dimorphic Hemorrhoids
# 468         168  Dimorphic Hemorrhoids
# 469         169  Dimorphic Hemorrhoids
# 470         170  Dimorphic Hemorrhoids
# 471         171  Dimorphic Hemorrhoids
# 478         178  Dimorphic Hemorrhoids
# 479         179  Dimorphic Hemorrhoids
# 482         182  Dimorphic Hemorrhoids
# 483         183  Dimorphic Hemorrhoids
# 484         184  Dimorphic Hemorrhoids
# 485         185  Dimorphic Hemorrhoids
# 487         187  Dimorphic Hemorrhoids
# 489         189  Dimorphic Hemorrhoids
# 490         190  Dimorphic Hemorrhoids
# 491         191  Dimorphic Hemorrhoids
# 492         192  Dimorphic Hemorrhoids
# 493         193  Dimorphic Hemorrhoids
#
#                                                   text  description_length  \
# 467  I've been constipated and it's really hard to ...                 210
# 468  Since I've been constipated, using the restroo...                 235
# 469  I've been constipated and it's really hard to ...                 210
# 470  Since I've been constipated, using the restroo...                 235
# 471  I've been constipated and it's really hard to ...                 210
# 478  Lately I've been experiencing constipation and...                 182
# 479  I've recently been suffering from constipation...                 189
# 482  My bowel motions have been really difficult fo...                 214
# 483  I've been experiencing a lot of bowel movement...                 226
# 484  I'm having a lot of trouble with my bowel move...                 206
# 485  I've been experiencing a lot of problems with ...                 235
# 487  Lately I've been experiencing constipation and...                 182
# 489  I've recently been suffering from constipation...                 189
# 490  I've been experiencing a lot of bowel movement...                 226
# 491  I'm having a lot of trouble with my bowel move...                 206
# 492  My bowel motions have been really difficult fo...                 214
# 493  I've been experiencing a lot of problems with ...                 235
#
#      word_count
# 467          42
# 468          42
# 469          42
# 470          42
# 471          42
# 478          29
# 479          29
# 482          40
# 483          40
# 484          40
# 485          42
# 487          29
# 489          29
# 490          40
# 491          40
# 492          40
# 493          42
#
#
# Duplicates for Arthritis:
#      Unnamed: 0      label                                               text  \
# 514         214  Arthritis  I've been feeling really weak in my muscles an...
# 515         215  Arthritis  My muscles have been feeling really weak, and ...
# 520         220  Arthritis  I've been feeling really weak in my muscles an...
# 521         221  Arthritis  My muscles have been feeling really weak, and ...
# 524         224  Arthritis  I've been experiencing stiffness and weakness ...
# 526         226  Arthritis  I've been experiencing stiffness and weakness ...
# 527         227  Arthritis  I've been feeling really weak in my muscles an...
#
#      description_length  word_count
# 514                 206          38
# 515                 208          36
# 520                 206          38
# 521                 208          36
# 524                 206          31
# 526                 206          31
# 527                 206          38
#
#
# Duplicates for Acne:
#      Unnamed: 0 label                                               text  \
# 556         256  Acne  A nasty rash has just appeared on my skin. Bla...
# 560         260  Acne  A skin rash with several pus-filled pimples an...
# 563         263  Acne  A nasty rash has just appeared on my skin. Bla...
# 569         269  Acne  I just developed a really nasty rash on my ski...
# 570         270  Acne  I've been dealing with a really nasty rash on ...
# 573         273  Acne  I just developed a really nasty rash on my ski...
# 574         274  Acne  I've been dealing with a really nasty rash on ...
# 580         280  Acne  A skin rash with several pus-filled pimples an...
#
#      description_length  word_count
# 556                 149          24
# 560                 135          22
# 563                 149          24
# 569                 155          29
# 570                 166          30
# 573                 155          29
# 574                 166          30
# 580                 135          22
#
#
# Duplicates for Bronchial Asthma:
#      Unnamed: 0             label  \
# 614          14  Bronchial Asthma
# 647          47  Bronchial Asthma
#
#                                                   text  description_length  \
# 614  I've been struggling with fatigue and a consta...                 173
# 647  I've been struggling with fatigue and a consta...                 173
#
#      word_count
# 614          31
# 647          31
#
#
# Duplicates for Migraine:
#      Unnamed: 0     label                                               text  \
# 704         104  Migraine  I've been facing visual disruptions, seeing th...
# 706         106  Migraine  I've been facing visual disruptions, seeing th...
# 737         137  Migraine  Along with excessive appetite, a stiff neck, h...
# 738         138  Migraine  Along with excessive appetite, a stiff neck, h...
# 742         142  Migraine  I have been experiencing acidity, indigestion,...
# 748         148  Migraine  I have been experiencing acidity, indigestion,...
#
#      description_length  word_count
# 704                  91          12
# 706                  91          12
# 737                 157          21
# 738                 157          21
# 742                 260          37
# 748                 260          37
#
#
# Duplicates for Cervical spondylosis:
#      Unnamed: 0                 label  \
# 773         173  Cervical spondylosis
# 778         178  Cervical spondylosis
#
#                                                   text  description_length  \
# 773  Back pain, a persistent cough, and numbness in...                 168
# 778  Back pain, a persistent cough, and numbness in...                 168
#
#      word_count
# 773          28
# 778          28
#
#
# Duplicates for Jaundice:
#      Unnamed: 0     label                                               text  \
# 814         214  Jaundice  I've been exhausted and experiencing nausea an...
# 815         215  Jaundice  I have been suffering from itching, vomiting, ...
# 816         216  Jaundice  I've been feeling scratchy, sick, and worn out...
# 817         217  Jaundice  The itch, the nausea, and the weariness have b...
# 819         219  Jaundice  I have been experiencing intense itching, vomi...
# 820         220  Jaundice  I've been feeling extremely scratchy, sick, an...
# 821         221  Jaundice  I've been feeling extremely scratchy, sick, an...
# 822         222  Jaundice  I've been feeling extremely scratchy, sick, an...
# 824         224  Jaundice  I've felt really scratchy, nauseated, and worn...
# 825         225  Jaundice  I have been having severe itching, vomiting, a...
# 826         226  Jaundice  I've been feeling really scratchy, dizzy, and ...
# 827         227  Jaundice  I've been experiencing intense itchiness, naus...
# 834         234  Jaundice  I've been exhausted and experiencing nausea an...
# 835         235  Jaundice  I have been suffering from itching, vomiting, ...
# 836         236  Jaundice  I've been feeling scratchy, sick, and worn out...
# 837         237  Jaundice  The itch, the nausea, and the weariness have b...
# 838         238  Jaundice  I have been experiencing intense itching, vomi...
# 839         239  Jaundice  I've been feeling extremely scratchy, sick, an...
# 840         240  Jaundice  I've felt really scratchy, nauseated, and worn...
# 841         241  Jaundice  I have been having severe itching, vomiting, a...
# 842         242  Jaundice  I've been feeling really scratchy, dizzy, and ...
# 843         243  Jaundice  I've been experiencing intense itchiness, naus...
#
#      description_length  word_count
# 814                 204          33
# 815                 198          36
# 816                 180          33
# 817                 201          35
# 819                 202          37
# 820                 213          35
# 821                 213          35
# 822                 213          35
# 824                 180          32
# 825                 191          35
# 826                 192          33
# 827                 184          30
# 834                 204          33
# 835                 198          36
# 836                 180          33
# 837                 201          35
# 838                 202          37
# 839                 213          35
# 840                 180          32
# 841                 191          35
# 842                 192          33
# 843                 184          30
#
#
# Duplicates for Malaria:
#      Unnamed: 0    label                                               text  \
# 851         251  Malaria  I've had a high temperature, vomiting, chills,...
# 852         252  Malaria  I've had a high temperature, vomiting, chills,...
# 857         257  Malaria  I've been experiencing severe body itchiness, ...
# 859         259  Malaria  I've been experiencing severe body itchiness, ...
# 862         262  Malaria  I have a high fever, severe itching, chills, a...
# 863         263  Malaria  I have a high temperature, vomiting, chills, a...
# 866         266  Malaria  I have a high fever, severe itching, chills, a...
# 867         267  Malaria  I have a high temperature, vomiting, chills, a...
# 869         269  Malaria  I've had a high temperature, vomiting, chills,...
# 873         273  Malaria  I've had a high temperature, vomiting, chills,...
# 890         290  Malaria  I have a high fever, severe itching, chills, a...
# 894         294  Malaria  I have a high fever, severe itching, chills, a...
#
#      description_length  word_count
# 851                 154          28
# 852                 154          28
# 857                 210          35
# 859                 210          35
# 862                 175          30
# 863                 176          30
# 866                 175          30
# 867                 176          30
# 869                 181          32
# 873                 181          32
# 890                 179          33
# 894                 179          33
#
#
# Duplicates for gastroesophageal reflux disease:
#       Unnamed: 0                            label  \
# 1026         126  gastroesophageal reflux disease
# 1033         133  gastroesophageal reflux disease
# 1048         148  gastroesophageal reflux disease
# 1049         149  gastroesophageal reflux disease
#
#                                                    text  description_length  \
# 1026  I'm not in the mood to eat, and swallowing is ...                 197
# 1033  Even when I don't have anything acidic in my s...                 152
# 1048  Even when I don't have anything acidic in my s...                 152
# 1049  I'm not in the mood to eat, and swallowing is ...                 197
#
#       word_count
# 1026          32
# 1033          30
# 1048          30
# 1049          32

# %%
# Remove duplicates
# Loop through each disease to drop duplicates while retaining one instance
for disease in df['label'].unique():
    disease_mask = (df['label'] == disease)  # Create a mask for rows of the specific disease
    duplicates_mask = df[disease_mask].duplicated(subset='text', keep='first')  # Identify duplicates for the disease

    # Combine the masks using logical AND to drop duplicates only for the specific disease
    df.drop(df[disease_mask & duplicates_mask].index, inplace=True)

print(df)
# Out:
#       Unnamed: 0      label  \
# 0              0  Psoriasis
# 1              1  Psoriasis
# 2              2  Psoriasis
# 3              3  Psoriasis
# 4              4  Psoriasis
# ...          ...        ...
# 1195         295   diabetes
# 1196         296   diabetes
# 1197         297   diabetes
# 1198         298   diabetes
# 1199         299   diabetes
#
#                                                    text  description_length  \
# 0     I have been experiencing a skin rash on my arm...                 141
# 1     My skin has been peeling, especially on my kne...                 138
# 2     I have been experiencing joint pain in my fing...                 148
# 3     There is a silver like dusting on my skin, esp...                 164
# 4     My nails have small dents or pits in them, and...                 140
# ...                                                 ...                 ...
# 1195  I'm shaking and trembling all over. I've lost ...                 146
# 1196  Particularly in the crevices of my skin, I hav...                 131
# 1197  I regularly experience these intense urges and...                 142
# 1198  I have trouble breathing, especially outside. ...                 150
# 1199  I constantly sneeze and have a dry cough. My i...                 168
#
#       word_count
# 0             28
# 1             23
# 2             28
# 3             32
# 4             27
# ...          ...
# 1195          25
# 1196          25
# 1197          23
# 1198          24
# 1199          29
#
# [1153 rows x 5 columns]

# %%
df.shape
# Out:
# (1153, 5)

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
# Save the modified dataframe as a csv file
df.to_csv('new_df.csv', index=False)
